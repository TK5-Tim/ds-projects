# %%
import sportsdataverse as sdv
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
nhl_df = sdv.nhl.load_nhl_pbp(seasons=range(2022,2023))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]/Users/keltim01/git_repos/TK5/sportsdataverse-py/sportsdataverse/nhl/nhl_loaders.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(i_data)
# 100%|██████████| 1/1 [00:12<00:00, 12.03s/it]

# %%
nhl_df.head()
# Out:
#        event_type           event  \
# 0  GAME_SCHEDULED  Game Scheduled
# 1          CHANGE          Change
# 2          CHANGE          Change
# 3         FACEOFF         Faceoff
# 4             HIT             Hit
#
#                                          description  period  period_seconds  \
# 0                                     Game Scheduled       1               0
# 1  ON: Jeff Carter, Kris Letang, Brian Dumoulin, ...       1               0
# 2  ON: Ryan McDonagh, Ondrej Palat, Nikita Kucher...       1               0
# 3      Jeff Carter faceoff won against Brayden Point       1               0
# 4                       Ondrej Palat hit Jeff Carter       1              18
#
#    period_seconds_remaining  game_seconds  game_seconds_remaining  home_score  \
# 0                    1200.0             0                    3600         0.0
# 1                    1200.0             0                    3600         0.0
# ...

# %%
nhl_df.columns
# Out:
# Index(['event_type', 'event', 'description', 'period', 'period_seconds',
#        'period_seconds_remaining', 'game_seconds', 'game_seconds_remaining',
#        'home_score', 'away_score',
#        ...
#        'event_player_4_type', 'event_player_4_id', 'event_player_4_name',
#        'event_player_4_link', 'penalty_severity', 'penalty_minutes',
#        'home_on_6', 'away_on_6', 'away_on_7', 'home_on_7'],
#       dtype='object', length=107)

# %%
nhl_df.season.unique()
# Out:
# array([2022], dtype=int32)

# %%
nhl_df.game_id.unique()
# Out:
# array([2021020001, 2021020002, 2021020003, ..., 2021030414, 2021030415,
#        2021030416], dtype=int32)

# %%
nhl_df = sdv.nhl.load_nhl_schedule(seasons=range(2023,2024))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]/Users/keltim01/git_repos/TK5/sportsdataverse-py/sportsdataverse/nhl/nhl_loaders.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(i_data)
# 100%|██████████| 1/1 [00:00<00:00,  3.48it/s]

# %%
nhl_df.head()
# Out:
#       game_id                               link game_type_abbreviation  \
# 0  2022020805  /api/v1/game/2022020805/feed/live                      R
# 1  2022020806  /api/v1/game/2022020806/feed/live                      R
# 2  2022020802  /api/v1/game/2022020802/feed/live                      R
# 3  2022020803  /api/v1/game/2022020803/feed/live                      R
# 4  2022020804  /api/v1/game/2022020804/feed/live                      R
#
#    season_full            game_date_time status_abstract_game_state  \
# 0     20222023 2023-02-02 00:30:00+00:00                      Final
# 1     20222023 2023-02-02 00:30:00+00:00                      Final
# 2     20222023 2023-02-01 00:00:00+00:00                      Final
# 3     20222023 2023-02-01 00:00:00+00:00                      Final
# 4     20222023 2023-02-01 00:00:00+00:00                      Final
#
#    status_coded_game_state status_detailed_state  status_status_code  \
# ...

# %%
nhl_box_df = sdv.nhl.load_nhl_player_boxscore(seasons=range(2023,2024))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]/Users/keltim01/git_repos/TK5/sportsdataverse-py/sportsdataverse/nhl/nhl_loaders.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(i_data)
# 100%|██████████| 1/1 [00:00<00:00,  1.15it/s]

# %%
np.unique(nhl_box_df[['player_full_name', 'position_code']].values)
# Out:
# array(['A.J. Greer', 'Aaron Dell', 'Aaron Ekblad', 'Aatu Raty',
#        'Adam Beckman', 'Adam Boqvist', 'Adam Erne', 'Adam Fox',
#        'Adam Henrique', 'Adam Larsson', 'Adam Lowry', 'Adam Pelech',
#        'Adam Ruzicka', 'Adin Hill', 'Adrian Kempe', 'Akira Schmid',
#        'Alec Martinez', 'Alec Regula', 'Aleksander Barkov',
#        'Aleksi Heponiemi', 'Alex Barré-Boulet', 'Alex Belzile',
#        'Alex DeBrincat', 'Alex Galchenyuk', 'Alex Goligoski',
#        'Alex Iafallo', 'Alex Killorn', 'Alex Lyon', 'Alex Nedeljkovic',
#        'Alex Newhook', 'Alex Ovechkin', 'Alex Pietrangelo',
#        'Alex Stalock', 'Alex Tuch', 'Alex Turcotte', 'Alex Wennberg',
#        'Alexandar Georgiev', 'Alexander Alexeyev', 'Alexander Barabanov',
#        'Alexander Edler', 'Alexander Holtz', 'Alexander Kerfoot',
#        'Alexander Romanov', 'Alexandre Carrier', 'Alexey Toropchenko',
#        'Alexis Lafrenière', 'Aliaksei Protas', 'Anders Bjork',
# ...

# %%
nhl_box_df[['player_full_name', 'position_code']].groupby('player_full_name').first().to_csv('nhl_players_22_23.csv')
