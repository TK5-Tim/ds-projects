# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Blasting Nobody Like U by 4*Town From Turning Red Pixar Movie all 40 Minutes (gonna be funny in Spotify Wrapped)

# %%
df_sea = pd.read_csv('cleaned.csv')

# %%
df_sea.head(10)
# Out:
#       Date  year  month data-type hemisphere  extent
# 0  11 1978  1978     11   Goddard          N   11.65
# 1  12 1978  1978     12   Goddard          N   13.67
# 2   1 1979  1979      1   Goddard          N   15.41
# 3   2 1979  1979      2   Goddard          N   16.18
# 4   3 1979  1979      3   Goddard          N   16.34
# 5   4 1979  1979      4   Goddard          N   15.45
# 6   5 1979  1979      5   Goddard          N   13.86
# 7   6 1979  1979      6   Goddard          N   12.53
# 8   7 1979  1979      7   Goddard          N   10.31
# 9   8 1979  1979      8   Goddard          N    8.04

# %%
df_sea_one_month = df_sea[df_sea['month']==11]

# %%
figtest, axtest = plt.subplots()
sns.lineplot(df_sea.loc[df_sea['month']==1,'year'],df_sea.loc[df_sea['month']==1,'extent'])
axtest.axhline(df_sea.loc[df_sea['month']==1,'extent'].mean())
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig, ax = plt.subplots(1,12,sharex=True,sharey=True,figsize=(8,6))
spines = ["top","right","bottom","left"]
plt.style.use('default')
for i in range(13):
    ax[i].plot(df_sea.loc[df_sea['month']==i-1,'year'],df_sea.loc[df_sea['month']==i-1,'extent'],c="seagreen")
    ax[i].axhline(df_sea.loc[df_sea['month']==i-1,'extent'].mean(),c='blue')
    ax[i].set_facecolor("lightgrey")    
    ax[i].get_xaxis().set_visible(False)
    ax[i].get_yaxis().set_visible(False)
plt.axis('off')
plt.savefig('vizz_buzz_pilot_03')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-93-77c424ba2bfc> in <module>
#       3 plt.style.use('default')
#       4 for i in range(13):
# ----> 5     ax[i].plot(df_sea.loc[df_sea['month']==i-1,'year'],df_sea.loc[df_sea['month']==i-1,'extent'],c="seagreen")
#       6     ax[i].axhline(df_sea.loc[df_sea['month']==i-1,'extent'].mean(),c='blue')
#       7     ax[i].set_facecolor("lightgrey")
#
# IndexError: index 12 is out of bounds for axis 0 with size 12
